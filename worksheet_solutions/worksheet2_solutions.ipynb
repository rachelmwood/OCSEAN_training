# %% [markdown]
# # Introduction to Python for Qualitative Researchers - Worksheet 2
# This worksheet is intended for you to practice what you have learnt in the second day of the training. It consists of some tasks where you will use the tools learnt to write your own solution.

# %% [markdown]
# ## Task 1
#
# ### Part 1
#
# Create a list containing 5 different animal types, for example:
#
# * cat
# * dog
# * elephant
# * minnow
# * beaver
#
# Print the list to the screen

# %%
#Write you answer here
animals = ['cat', 'dog', 'elephant', 'minnow', 'beaver']
print(animals)
# Out:
# ['cat', 'dog', 'elephant', 'minnow', 'beaver']

# %% [markdown]
# ### Part 2
#
# Write a loop which will print out each of the animals in the list, prefixed with Species:. For example the output could look like:
#
# - Species: cat
# - Species: dog
# - Species: elephant
# - Species: minnow
# - Species: beaver

# %%
#Write your answer here

for animal in animals:
  print("Species:", animal)
# Out:
# Species: cat
# Species: dog
# Species: elephant
# Species: minnow
# Species: beaver

# %% [markdown]
# ## Task 2
#
# Create a list containing 10 different numbers, ranging from 0 to 100. For example: 65, 54, 17, 78, 66, 24, 32, 80, 79, 95.
#
# Write a loop which will print out only those numbers which are larger than 50.

# %%
my_numbers = [65, 54, 17, 78, 66, 24, 32, 80, 79, 95]

for numbers in my_numbers:
  if numbers > 50:
    print(numbers)
# Out:
# 65
# 54
# 78
# 66
# 80
# 79
# 95

# %% [markdown]
# ## Task 3
#
# Create a loop which iterates over the numbers from 1 to 20. Inside the loop:
# - If the number is divisible by three then print “ook”
# - If the number is divisible by both three and five then print “foo”,
# - If the number is not divisible by either then just print the number.
#
# **Hint:** We need to use a new operator: `%`. `%` finds the remainder from a division. For example `6 % 4` equals `2`, as 4 goes into 6 once with a remainder of 2.
#
# Also, take care in the order that you do your `if-else`.

# %%
for number in range(1,21):
  if number % 3 == 0 and number % 5 == 0:
    print("foo")
  elif number % 3 == 0:
    print("ook")
  else:
    print(number)
# Out:
# 1
# 2
# ook
# 4
# 5
# ook
# 7
# 8
# ook
# 10
# 11
# ook
# 13
# 14
# foo
# 16
# 17
# ook
# 19
# 20

# %% [markdown]
# ## Task 4
#
# Take the following code:
#
#
# ```
# my_list = [5, 7, 34, 5, 3, 545]
#
# big_numbers = []
# for num in my_list:
#     if num > 10:
#         big_numbers.append(num)
#
# print(big_numbers)
# ```
#
# and convert the data-processing parts to a function called `big` which can be called like:
#
# ```
# my_list = [5, 7, 34, 5, 3, 545]
#
# large_numbers = big(my_list)
#
# print(large_numbers)
# ```
#
# giving
#
# `[34, 545]`
#
#
# Be careful to pay attention to the indentation, ensuring that it is consistent with the original code. Particularly, note that the return statement will cause the function to exit, so make sure that it doesn’t run until after the loop has finished.

# %%
def big(mylist):
  big_numbers = []
  for number in mylist:
    if number > 10:
      big_numbers.append(number)

  return big_numbers

# %%
numbers = [7, 12, 4, 1, 25]

big(numbers)
# Out:
# [12, 25]

# %% [markdown]
# ## Task 5
#
# Make a dictionary with the keys being the name of countries and the value being the country's capital city.
#
# Create a loop for the dictionary that prints something like "The capital of France is Paris" for all items.

# %%
capitals = {
    "France" : "Paris",
    "Japan" : "Tokyo",
    "Egypt" : "Cairo"
}

for country, city in capitals.items():
  print(f'The capital of {country} is {city}')
# Out:
# The capital of France is Paris
# The capital of Japan is Tokyo
# The capital of Egypt is Cairo
