# %% [markdown]
# # Introduction to Python for Qualitative Researchers - Worksheet 3
# This worksheet is intended for you to practice what you have learnt in the third day of the training. It consists of some tasks where you will use the tools learnt to write your own solution.

# %% [markdown]
# For this worksheet you will be using the `titanic.csv` file that contains the following information about the passengers and crew aboard the RMS Titanic:
# - `name`: strings with the name of the passenger.
# - `gender`: “male” or “female”.
# - `age`: a float with the persons age on the day of the sinking. The age of babies (under 12 months) is given as a fraction of one year.
# - `class`: a string specifying the class (1st, 2nd or 3rd) for passengers or the type of service aboard for crew members.
# embarked: the persons place of of embarkment.
# - `country`: the persons home country.
# ticketno: the persons ticket number (NA for crew members).
# - `fare`: the ticket price (NA for crew members, musicians and employees of the shipyard company).
# - `sibsp`: a number specifying the number if siblings/spouses aboard.
# - `parch`: a number specifying the number of parents/children aboard.
# - `survived`: a string (“no” or “yes”) specifying whether the person has survived the sinking.

# %% [markdown]
# # Task 1: Loading the Data
# Load the pandas library and `titanic.csv` file into your workspace

# %%
import pandas as pd

titanic = pd.read_csv("titanic.csv")

titanic
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
# ...

# %% [markdown]
# # Task 2: Summarising the data
# ## Part 1
# Find the average age of all the people on board.

# %%
titanic['age'].mean()
# Out:
# np.float64(30.436734693877504)

# %% [markdown]
# ## Part 2
# Use a filter to select only the males on board

# %%
all_male = titanic[titanic['gender'] == 'male']
all_male
# Out:
#                                name gender   age             class embarked  \
# 0               Abbing, Mr. Anthony   male  42.0               3rd        S
# 1         Abbott, Mr. Eugene Joseph   male  13.0               3rd        S
# 2       Abbott, Mr. Rossmore Edward   male  16.0               3rd        S
# 5     Abelseth, Mr. Olaus Jørgensen   male  25.0               3rd        S
# 6               Abelson, Mr. Samuel   male  30.0               2nd        C
# ...                             ...    ...   ...               ...      ...
# 2202               Wynn, Mr. Walter   male  41.0         deck crew        B
# 2203            Yearsley, Mr. Harry   male  40.0  victualling crew        S
# 2204       Young, Mr. Francis James   male  32.0  engineering crew        S
# 2205            Zanetti, Sig. Minio   male  20.0  restaurant staff        S
# 2206             Zarracchi, Sig. L.   male  26.0  restaurant staff        S
#
# ...

# %% [markdown]
# ## Part 3
# Find the average age of the males on board

# %%
all_male['age'].mean()

titanic[titanic['gender'] == 'male']['age'].mean()
# Out:
# np.float64(30.83231351981346)

# %% [markdown]
# # Task 3: Filtering
# ## Part 1
# Use a filter to select only the people in 3rd class

# %%
titanic[titanic['class'] == '3rd']
# Out:
#                                 name  gender   age class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0   3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0   3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0   3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0   3rd        S
# ...                              ...     ...   ...   ...      ...
# 1313              Yūsuf, Mrs. Kātrīn  female  23.0   3rd        C
# 1315       Zakarian, Mr. Mapriededer    male  22.0   3rd        C
# 1316             Zakarian, Mr. Ortin    male  27.0   3rd        C
# 1317               Zenni, Mr. Philip    male  25.0   3rd        C
# 1318             Zimmermann, Mr. Leo    male  29.0   3rd        S
#
#             country  ticketno     fare  sibsp  parch survived
# 0     United States    5547.0   7.1100    0.0    0.0       no
# ...

# %% [markdown]
# ## Part 2
# Create a DataFrame which only contains the passengers on the ship (those in first, second or third class).

# %%
passengers = titanic[(titanic['class'] == '1st') |
                     (titanic['class'] == '2nd') |
                     (titanic['class'] == '3rd')]
passengers
# Out:
#                                 name  gender   age class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0   3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0   3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0   3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0   3rd        S
# ...                              ...     ...   ...   ...      ...
# 1314          Yvois, Miss. Henriette  female  24.0   2nd        S
# 1315       Zakarian, Mr. Mapriededer    male  22.0   3rd        C
# 1316             Zakarian, Mr. Ortin    male  27.0   3rd        C
# 1317               Zenni, Mr. Philip    male  25.0   3rd        C
# 1318             Zimmermann, Mr. Leo    male  29.0   3rd        S
#
#             country  ticketno     fare  sibsp  parch survived
# 0     United States    5547.0   7.1100    0.0    0.0       no
# ...

# %% [markdown]
# # Task 4: Plotting
# ## Part 1
# Plot and compare the distribution of ages for males and females.

# %%
import seaborn as sns
sns.displot(
    data = titanic,
    x = 'age',
    hue = 'gender',
)

# %% [markdown]
# ## Part 2
# Do the same for class.

# %%
import seaborn as sns
sns.displot(
    data = titanic,
    x = 'class',
    hue = 'gender',
).set_xticklabels(rotation=30)

# %% [markdown]
# # Task 5: Explore!
#
# Explore the data and see what you can find. For example, try exploring what the main factors predicting survival were.

# %%
sns.displot(
    data = passengers,
    x = 'age',
    hue = 'class',
    col = 'survived'
)
