# %% [markdown]
# # Introduction to Python for Qualitative Researchers - Worksheet 1
# This worksheet is intended for you to practice what you have learnt in the first day of the training. It consists of some tasks where you will use the tools learnt to write your own solution.

# %% [markdown]
# ## Task 1:
#
# Without running any code, guess what data types each of these variables would have:
# ```
# x = 32
# number_of_participants = "1017"
# Friday = True
# y = float(1)
# a = 10<8
# ```

# %% [markdown]
# ### Part 2
#
# Use a function from the Day 1 notebook to turn `x` into a string

# %% [markdown]
# ## Task 2:
# ### Part 1
# Use the cell below to create a list containing 5 different animals:
#
# - cat
# - dog
# - elephant
# - minnow
# - beaver
#
# Print out the list to the screen.

# %% [markdown]
# ### Part 2
# Add an entry for monkey to the list you just made.

# %% [markdown]
# ### Part 3
# Remove the beaver entry in the list

# %% [markdown]
# ### Part 4
#
# Swap the positions of cat and elephant in the list.

# %% [markdown]
# ## Task 3:
# ### Part 1
#
# Make a dictionary with the keys being the name of countries and the value being the country's capital city.

# %% [markdown]
# ### Part 2
#
# Print the capital city for a chosen country.
